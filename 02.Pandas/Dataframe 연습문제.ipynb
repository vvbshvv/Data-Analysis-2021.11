# %% [markdown]
# 연습 문제 4.1.1
#
# (1) 임의로 두 개의 시리즈 객체를 만든다. 모두 문자열 인덱스를 가져야 하며 두 시리즈에 공통적으로 포함되지 않는 라벨이 있어야 한다.
#
# (2) 위에서 만든 두 시리즈 객체를 이용하여 사칙 연산을 한다.

# %%
import pandas as pd

s = pd.Series({'국어':80,'영어':70,'수학':95})
f = pd.Series({'사회':70,'과학':50,'수학':20})
s+f
# Out:
# 과학      NaN
# 국어      NaN
# 사회      NaN
# 수학    115.0
# 영어      NaN
# dtype: float64

# %% [markdown]
# 연습 문제 4.1.2
#
# 다음 조건을 만족하는 임의의 데이터프레임을 하나 만든다.
#
# (1) 열의 갯수와 행의 갯수가 각각 5개 이상이어야 한다.
#
# (2) 열에는 정수, 문자열, 실수 자료형 데이터가 각각 1개 이상씩 포함되어 있어야 한다.

# %%
import numpy as np
index = ['색깔','년식','스피드','내구도','사고횟수']
np.random.seed(2021)
df = pd.DataFrame(np.random.randint(1,100,25).reshape(5,5),
                    columns=['bmw','benz','ford','citroen','honda'],index=index)

df.loc['이자율']=[0.01,0.02,0.03,0.04,0.01]
df.loc['구매희망']=['1순위','2순위','3순위','4순위','5순위']
df
# Out:
#        bmw  benz  ford citroen honda
# 색깔    86.0  58.0   1.0    95.0  87.0
# 년식    45.0  63.0  92.0    30.0  22.0
# 스피드   94.0  25.0  13.0    71.0  71.0
# 내구도   34.0   8.0   2.0    98.0  27.0
# 사고횟수  67.0  49.0  64.0    50.0  17.0
# 이자율   0.01  0.02  0.03    0.04  0.01
# 구매희망   1순위   2순위   3순위     4순위   5순위

# %% [markdown]
# 연습 문제 4.1.3
#
# 다음 데이터프레임에서 지정하는 데이터를 뽑아내거나 처리하라.
#
# data = {
#     "국어": [80, 90, 70, 30],
#     "영어": [90, 70, 60, 40],
#     "수학": [90, 60, 80, 70],
# }
# columns = ["국어", "영어", "수학"]
# index = ["춘향", "몽룡", "향단", "방자"]
# df = pd.DataFrame(data, index=index, columns=columns)
# (1) 모든 학생의 수학 점수를 시리즈로 나타낸다.
#
# (2) 모든 학생의 국어와 영어 점수를 데이터 프레임으로 나타낸다.
#
# (3) 모든 학생의 각 과목 평균 점수를 새로운 열로 추가한다.
#
# (4) 방자의 영어 점수를 80점으로 수정하고 평균 점수도 다시 계산한다.
#
# (5) 춘향의 점수를 데이터프레임으로 나타낸다.
#
# (6) 향단의 점수를 시리즈로 나타낸다.

# %%
data = {
    "국어": [80, 90, 70, 30],
    "영어": [90, 70, 60, 40],
    "수학": [90, 60, 80, 70],
}
columns = ["국어", "영어", "수학"]
index = ["춘향", "몽룡", "향단", "방자"]
df = pd.DataFrame(data, columns=columns, index=index)
df['수학']  #dataframe는 시리즈 + 인덱스
type(df['수학'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#     국어  영어  수학
# 춘향  80  90  90
# 몽룡  90  70  60
# 향단  70  60  80
# 방자  30  40  70

# %%
df[['국어','영어']]
# Out:
#     국어  영어
# 춘향  80  90
# 몽룡  90  70
# 향단  70  60
# 방자  30  40

# %%
df.loc['평균'] = df.mean()
df['평균'] = df.mean(axis=1)
df
# Out:
#       국어    영어    수학         평균
# 춘향  80.0  90.0  90.0  86.666667
# 몽룡  90.0  70.0  60.0  73.333333
# 향단  70.0  60.0  80.0  70.000000
# 방자  30.0  40.0  70.0  46.666667
# 평균  67.5  65.0  75.0  69.166667

# %%
df['영어']['방자'] = 80
df.loc['평균1'] = df.mean()
df['평균'] = df.mean(axis=1)
df.drop(columns=['평균'], inplace=True) #열 삭제!!!!!!!!!!!
df.drop(['평균']) #행 삭제!!!!!!!!!!!
# Out:
#        국어    영어    수학
# 춘향   80.0  90.0  90.0
# 몽룡   90.0  70.0  60.0
# 향단   70.0  60.0  80.0
# 방자   30.0  80.0  70.0
# 평균1  67.5  73.0  75.0

# %%
df.head(3).tail(1) #향단의 데이터 프레임만 추출
# Out:
#       국어    영어    수학
# 향단  70.0  60.0  80.0

# %%
df.T['춘향'] #행,열 변경 후 춘향 데이터만 추출(시리즈로 추출)
# Out:
# 국어    80.0
# 영어    90.0
# 수학    90.0
# Name: 춘향, dtype: float64

# %%
df.T['향단']
# Out:
# 국어    70.0
# 영어    60.0
# 수학    80.0
# Name: 향단, dtype: float64

# %% [markdown]
# 연습 문제 4.3.1
#
# 모든 행과 열에 라벨을 가지는 5 x 5 이상의 크기를 가지는 데이터프레임을 만든다.
#
# 10가지 이상의 방법으로 특정한 행과 열을 선택한다.

# %%
columns = ['1','2','3','4','5']
index = ['0','9','8','7','6']
df=pd.DataFrame(np.random.randint(1,100,25).reshape(5,5), columns=columns, index=index)
df
# Out:
#     1   2   3   4   5
# 0  51  55  53  94   6
# 9  50  39  15  72  86
# 8  71  42  22  26  11
# 7  37  20  58  83  91
# 6  16  41  77  54  12

# %%
df=pd.DataFrame(np.arange(25).reshape(5,5), columns=list('abcde'), index=list('qwert'))
df
# Out:
#     a   b   c   d   e
# q   0   1   2   3   4
# w   5   6   7   8   9
# e  10  11  12  13  14
# r  15  16  17  18  19
# t  20  21  22  23  24

# %%
df['c']['q'], df['c'][2], df.c['q'], df.c[2], df.c.q
# Out:
# (2, 12, 2, 12, 2)

# %%
#loc indexer
df.loc['q','c'], df.loc['q'][2], df.loc['q']['c']
# Out:
# (2, 2, 2)

# %%
#iloc indexer
df.iloc[2,2], df.iloc[2]['c'], df.iloc[2][2]
# Out:
# (12, 12, 12)

# %%
import numpy as np
import pandas as pd
columns = ['male','female']
np.random.seed(2021)
df=pd.DataFrame(np.random.randint(1,1001,4).reshape(2,2), columns=columns)
df.loc['평균'] = df.mean()
df['평균'] = df.mean(axis=1)
df
# Out:
#      male  female     평균
# 0   117.0   342.0  229.5
# 1    58.0   129.0   93.5
# 평균   87.5   235.5  161.5

# %%
import pandas as pd
import numpy as np
values = ['10','45','13']
df = pd.DataFrame(values,columns=['age'])
df['name']=['George','Damien','Ingrid']
df['gender']=['male','male','female']
df.loc['네번째']=['머','나올지','궁금해?']
df
# Out:
#     age    name  gender
# 0    10  George    male
# 1    45  Damien    male
# 2    13  Ingrid  female
# 네번째   머     나올지    궁금해?

# %%
df.drop(['네번째'], inplace=True)

# %%
df.drop(columns=['gender'])
# Out:
#   age    name
# 0  10  George
# 1  45  Damien
# 2  13  Ingrid

# %%
df.T.head(2).tail(1)
# Out:
#            0       1       2
# name  George  Damien  Ingrid

# %%
df['license'] = ['o','o','x']
df
# Out:
#   age    name  gender license
# 0  10  George    male       o
# 1  45  Damien    male       o
# 2  13  Ingrid  female       x

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic['pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic['pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['age'].fillna(titanic.age.mean(), inplace=True)

# %%
titanic.drop(columns=['deck'], inplace=True)

# %%
titanic.dropna(subset=['embarked'], inplace=True)
titanic.dropna(subset=['embark_town'], inplace=True)
titanic.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
titanic['child/adult'] = titanic.apply(lambda x : 'child' if x.age<19 else 'adult', axis=1)
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone child/adult
# 0     Third    man        True  Southampton    no  False       adult
# 1     First  woman       False    Cherbourg   yes  False       adult
# 2     Third  woman       False  Southampton   yes   True       adult
# 3     First  woman       False  Southampton   yes  False       adult
# 4     Third    man        True  Southampton    no   True       adult
# ..      ...    ...         ...          ...   ...    ...         ...
# 886  Second    man        True  Southampton    no   True       adult
# 887   First  woman       False  Southampton   yes   True       adult
# 888   Third  woman       False  Southampton    no  False       adult
# 889   First    man        True    Cherbourg   yes   True       adult
# 890   Third    man        True   Queenstown    no   True       adult
#
# [889 rows x 15 columns]

# %%
titanic.sex=titanic.sex.apply(lambda x : x.replace('fe', '여자'))

# %%
titanic
# Out:
#      survived  pclass   sex        age  sibsp  parch     fare embarked  \
# 0           0       3    남자  22.000000      1      0   7.2500        S
# 1           1       1  여자남자  38.000000      1      0  71.2833        C
# 2           1       3  여자남자  26.000000      0      0   7.9250        S
# 3           1       1  여자남자  35.000000      1      0  53.1000        S
# 4           0       3    남자  35.000000      0      0   8.0500        S
# ..        ...     ...   ...        ...    ...    ...      ...      ...
# 886         0       2    남자  27.000000      0      0  13.0000        S
# 887         1       1  여자남자  19.000000      0      0  30.0000        S
# 888         0       3  여자남자  29.699118      1      2  23.4500        S
# 889         1       1    남자  26.000000      0      0  30.0000        C
# 890         0       3    남자  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone child/adult
# 0     Third    man        True  Southampton    no  False       adult
# 1     First  woman       False    Cherbourg   yes  False       adult
# 2     Third  woman       False  Southampton   yes   True       adult
# 3     First  woman       False  Southampton   yes  False       adult
# 4     Third    man        True  Southampton    no   True       adult
# ..      ...    ...         ...          ...   ...    ...         ...
# 886  Second    man        True  Southampton    no   True       adult
# 887   First  woman       False  Southampton   yes   True       adult
# 888   Third  woman       False  Southampton    no  False       adult
# 889   First    man        True    Cherbourg   yes   True       adult
# 890   Third    man        True   Queenstown    no   True       adult
#
# [889 rows x 15 columns]

# %%
titanic['sex'].value_counts()
# Out:
# 남자      577
# 여자남자    312
# Name: sex, dtype: int64

# %%
titanic.age.mean()
# Out:
# 29.653446370674192

# %%
titanic.age=titanic.age.apply(lambda x : x.mean() if titanic.sex='남자')
# Out:
#   File "<ipython-input-430-d5819dba3c1d>", line 1
#     titanic.age=titanic.age.apply(lambda x : x.mean() if titanic.sex='남자')
#                                                                     ^
# SyntaxError: invalid syntax
